# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data = np.loadtxt("coord.dat")

# %%
plt.scatter(data[:,0],data[:,1])
plt.scatter(2.82035e+03, 2.11919e+03, facecolor="red")
plt.scatter(2.68091e+03, 1.72918e+03, facecolor="red")
plt.scatter(2.77283e+03, 1.96638e+03, facecolor="red")
# Out:
# <img src="data:image/png;base64,...">
